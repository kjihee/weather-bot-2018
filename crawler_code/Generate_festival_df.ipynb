# %% [markdown]
# # 모듈 및 패키지 불러오기
# - Selenium       : 동적페이지 불러오기
# - BeatifulSoup   : HTML 페이지 소스 불러오기
# - Pandas         : DataFrame 형태로 테이블을 저장하고 변환하기 위함
# - 내장함수. time : 각 페이지 크롤링 간 딜레이를 두기 위함
# - 내장함수. re   : 정규식을 통해 날짜 뽑아내기 위함
# - 내장함수. datetime : 날짜 값들을 datetime 데이터타입으로 저장하기 위함

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
from pandas import DataFrame, Series
import time
import re
import datetime

# %% [markdown]
# # Festival 목록 선언
# - 네이버 페이지 검색 시 http link 변경되는 부분에, 축제 항목 리스트 선언

# %%
# festival_categories = ['여름꽃축제','바다축제','여름먹거리축제','문화예술축제',
#                  '봄축제','벚꽃축제','전통문화축제','봄먹거리축제',
#                 '가을축제','단풍축제','대하전어축제','가을먹거리축제',
#                 '겨울축제','눈꽃축제','얼음낚시축제','얼음낚시축제']

# Example.
# link = "https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bk00&query=" + (이쪽에 들어가게 됨)
# driver.get(link)

# %% [markdown]
# # 초기 driver 객체의 크롬 접속

# %%
# driver = webdriver.Chrome('G:\chromedriver')

# %% [markdown]
# # 축제 페이지 세부내용 크롤링 작업

# %%
#data 담을 container 선언
# raw_data_list = []

#festival_list_count
# for categorie_order in range(len(festival_categories)):
#     input_link = "https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bk00&query=" +festival_categories[categorie_order]
#     print("#'%d'번 카테고리 '%s'" %(categorie_order,input_link))
#     driver.get(input_link)
#     #링크 접속 후 대기시간
#     time.sleep(5)
#     html = driver.page_source
#     soup = BeautifulSoup(html, 'html.parser')
    
#     #page_count
#     try:
#         page_number = soup.select("#_cs_seasonal_festival > div.ftv_lst > div.pg > span")
#         page_number = page_number[0].text.split("/")[1]
#     except Exception as e:
#         print("#초기 'page_number' 로딩 시 에러발생. \n 에러내용:", e)
#         page_number = '1'
#     print("#현재 페이지는 '%s' 전 페이지 수는 '%s장' 입니다."  %(festival_categories[categorie_order],page_number))
#     print("\n")
    
#     for page in range(int(page_number)):
#         print("#현재 동일페이지에서 '%s'번 시도중입니다."  %(page+1))
#         html = driver.page_source
#         soup = BeautifulSoup(html, 'html.parser')
#         notices = soup.select(" #_cs_seasonal_festival > div.ftv_lst > ul ")
#         notices = notices[0].text.strip().split("  ")
#         for number,n in enumerate(notices):
#             if n != '':
#                 print(number,n.strip())
#                 raw_data_list.append(n.strip())
#         if page_number != '1':
#             try:
#                 driver.find_element_by_xpath("""//*[@id="_cs_seasonal_festival"]/div[3]/div[2]/a[2]""").click()
#             except Exception as e:
#                 print("#'다음 목록'버튼 클릭 시 에러발생. \n 에러내용:", e)
#                 break
#         #링크 접속 후 대기시간
#         time.sleep(5)
#     print("\n")
    
# print("\n")
# print("\n")
# print("수고하셨습니다. 크롤링 작업이 끝났습니다.")

# %% [markdown]
# # 뽑아낸 페이지 소스 -> list로 분류

# %%
# before_dataframe = [[],[],[],[],[]]


# for number,i in enumerate(raw_data_list):
# #     print(i.strip().split(" "))
#     if (number % 2) == 0:
#         before_splited = re.findall("([\s\S]+?)(\d{4}.\d{2}.\d{2}~\d{4}.\d{2}.\d{2})",i)
#         try:
#             name, date= before_splited[0]
#             before_dataframe[0].append(name)
#             before_dataframe[1].append(datetime.datetime.strptime(date.split('~')[0],'%Y.%m.%d').date())
#             before_dataframe[2].append(datetime.datetime.strptime(date.split('~')[1],'%Y.%m.%d').date())
#         except IndexError as e:
#             before_dataframe[0].append(name)
#             before_dataframe[1].append(date.split('~')[0])
#             before_dataframe[2].append(None)

                                    
#     else:
#         before_dataframe[3].append(i.strip().split(" ")[0])
#         before_dataframe[4].append(i.strip().split(" ")[1])

# %% [markdown]
# # 분류된 리스트 -> 데이터 프레임형태로 변환 / 저장

# %%
# Festival_df = DataFrame(list(zip(*before_dataframe)),columns = ["name", "startdate", "enddate", "location_01","location_02"])
# Festival_df.to_csv('Festival_df.csv',index = False)

# %% [markdown]
# # 함수화 (저장하고자 하는 폴더)

# %%
def generate_festival_df(filepath = 'Festival_df.csv'):
    festival_categories = ['여름꽃축제','바다축제','여름먹거리축제','문화예술축제',
                     '봄축제','벚꽃축제','전통문화축제','봄먹거리축제',
                    '가을축제','단풍축제','대하전어축제','가을먹거리축제',
                    '겨울축제','눈꽃축제','얼음낚시축제','얼음낚시축제']
    driver = webdriver.Chrome('G:\chromedriver')


    #data 담을 container 선언
    raw_data_list = []

    #festival_list_count
    for categorie_order in range(len(festival_categories)):
        input_link = "https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&mra=bk00&query=" +festival_categories[categorie_order]
#         print("#'%d'번 카테고리 '%s'" %(categorie_order,input_link))
        driver.get(input_link)
        #링크 접속 후 대기시간
        time.sleep(5)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        #page_count
        try:
            page_number = soup.select("#_cs_seasonal_festival > div.ftv_lst > div.pg > span")
            page_number = page_number[0].text.split("/")[1]
        except Exception as e:
#             print("#초기 'page_number' 로딩 시 에러발생. \n 에러내용:", e)
            page_number = '1'
#         print("#현재 페이지는 '%s' 전 페이지 수는 '%s장' 입니다."  %(festival_categories[categorie_order],page_number))
#         print("\n")

        for page in range(int(page_number)):
#             print("#현재 동일페이지에서 '%s'번 시도중입니다."  %(page+1))
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            notices = soup.select(" #_cs_seasonal_festival > div.ftv_lst > ul ")
            notices = notices[0].text.strip().split("  ")
            for number,n in enumerate(notices):
                if n != '':
#                     print(number,n.strip())
                    raw_data_list.append(n.strip())
            if page_number != '1':
                try:
                    driver.find_element_by_xpath("""//*[@id="_cs_seasonal_festival"]/div[3]/div[2]/a[2]""").click()
                except Exception as e:
#                     print("#'다음 목록'버튼 클릭 시 에러발생. \n 에러내용:", e)
                    break
            #링크 접속 후 대기시간
            time.sleep(5)
#         print("\n")

#     print("\n")
#     print("\n")
#     print("수고하셨습니다. 크롤링 작업이 끝났습니다.")


    before_dataframe = [[],[],[],[],[]]


    for number,i in enumerate(raw_data_list):
    #     print(i.strip().split(" "))
        if (number % 2) == 0:
            before_splited = re.findall("([\s\S]+?)(\d{4}.\d{2}.\d{2}~\d{4}.\d{2}.\d{2})",i)
            try:
                name, date= before_splited[0]
                before_dataframe[0].append(name)
                before_dataframe[1].append(datetime.datetime.strptime(date.split('~')[0],'%Y.%m.%d').date())
                before_dataframe[2].append(datetime.datetime.strptime(date.split('~')[1],'%Y.%m.%d').date())
            except IndexError as e:
                before_dataframe[0].append(name)
                before_dataframe[1].append(date.split('~')[0])
                before_dataframe[2].append(None)


        else:
            before_dataframe[3].append(i.strip().split(" ")[0])
            before_dataframe[4].append(i.strip().split(" ")[1])

    Festival_df = DataFrame(list(zip(*before_dataframe)),columns = ["name", "startdate", "enddate", "location_01","location_02"])
    Festival_df.to_csv(filepath,index = False)

# %%
generate_festival_df()
# Out:
# 0 부여서동연꽃축제2018.07.06~2018.07.15
# 1 충남 부여군
# 2 세계조롱박축제2018.07.20~2018.08.19
# 3 충남 청양군
# 4 무주반딧불축제2018.09.01~2018.09.09
# 5 전북 무주군
# 6 아침고요수목원 무궁화축제2017.07.29~2017.09.03
# 7 경기 가평군
# 8 태백 해바라기축제2017.07.27~2017.08.13
# 9 강원 태백시
# 0 양평 메기수염축제2018.06.02~2018.08.31
# 1 경기 양평군
# 2 신촌물총축제2018.07.07~2018.07.08
# 3 서울 서대문구
# 4 포항국제불빛축제2018.07.25~2018.07.29
# 5 경북 포항시
# 6 정남진장흥물축제2018.07.27~2018.08.02
# 7 전남 장흥군
# 8 부산바다축제2018.08.01~2018.08.05
# 9 부산 수영구
# 10 고창 갯벌 축제2018.08.03~2018.08.05
# 11 전북 고창군
# 0 통영한산대첩축제2018.08.10~2018.08.14
# 1 경남 통영시
# 3 목포항구축제2018.10.05~2018.10.07
# 4 전남 목포시
# 6 부산항축제2018.05.25~2018.05.27
# 7 부산 영도구
# 9 해운대모래축제2018.05.19~2018.05.22
# 10 부산 해운대구
# 12 무창포 신비의 바닷길축제2017.09.09~2017.09.11
# 13 충남 보령시
# 15 울산 워터버블페스티벌2017.08.11~2017.08.12
# 16 울산 중구
# 0 영월 동강축제2017.08.03~2017.08.06
# 1 강원 영월군
# 3 물의나라 화천 쪽배축제2017.07.29~2017.08.13
# 4 강원 화천군
# 6 울산 서머페스티벌2017.07.22~2017.07.29
# 7 울산 중구
# 9 금강여울축제2017.07.15~2017.07.16
# 10 충남 금산군
# 12 청개구리 물놀이축제2017.07.07~2017.08.20
# 13 경기 고양시
# 15 춘천 호수별빛나라축제2017.06.02~2017.12.31
# 16 강원 춘천시
# 0 고창복분자와수박축제2018.06.22~2018.06.24
# 1 전북 고창군
# 2 대구치맥페스티벌2018.07.18~2018.07.22
# 3 대구 달서구
# 4 홍천 찰옥수수축제2018.07.27~2018.07.29
# 5 강원 홍천군
# 6 봉화은어축제2018.07.28~2018.08.04
# 7 경북 봉화군
# 8 진안고원 수박축제2018.08.04~2018.08.05
# 9 전북 진안군
# 10 영동포도축제2018.08.23~2018.08.26
# 11 충북 영동군
# 0 송도맥주축제(송도세계문화관광축제)2018.08.24~2018.09.01
# 9 강원 횡성군
# 10 완주와일드푸드축제2018.10.05~2018.10.07
# 11 전북 완주군
# 0 금산인삼축제2018.10.05~2018.10.14
# 1 충남 금산군
# 3 임실N치즈축제2018.10.06~2018.10.09
# 4 전북 임실군
# 6 논산강경젓갈축제2018.10.10~2018.10.14
# 7 충남 논산시
# 9 이천쌀문화축제2018.10.17~2018.10.21
# 10 경기 이천시
# 12 순창장류축제2018.10.19~2018.10.21
# 13 전북 순창군
# 15 여주 오곡나루축제2018.10.26~2018.10.28
# 16 경기 여주시
# 0 강릉세계겨울커피축제 재즈 프레소2018.02.09~2018.02.25
# 1 강원 강릉시
# 3 파주장단콩축제2017.11.24~2017.11.26
# 4 경기 파주시
# 6 청송도깨비사과축제2017.11.03~2017.11.06
# 7 경북 청송군
# 9 김해 진영단감축제2017.11.03~2017.11.05
# 10 경남 김해시
# 12 전주비빔밥축제2017.10.26~2017.10.29
# 13 전북 전주시
# 15 경북영주 풍기인삼축제2017.10.21~2017.10.29
# 16 경북 영주시
# 0 충주농산물 한마당 축제2017.10.21~2017.10.22
# 1 충북 충주시
# 3 문경 사과축제2017.10.14~2017.10.29
# 4 경북 문경시
# 6 보은대추축제2017.10.13~2017.10.22
# 7 충북 보은군
# 9 양양송이축제2017.09.29~2017.10.01
# 10 강원 양양군
# 12 문경 오미자축제2017.09.15~2017.09.17
# 13 경북 문경시
# 0 얼음나라 화천산천어축제2018.01.06~2018.01.28
# 1 강원 화천군
# 2 가평자라섬씽씽축제2018.01.06~2018.02.18
# 3 경기 가평군
# 4 홍천강 인삼송어 축제2018.01.05~2018.01.21
# 5 강원 홍천군
# 6 파주 송어 축제2017.12.23~2018.02.18
# 7 경기 파주시
# 8 물맑은 양평빙어축제2017.12.23~2018.02.18
# 9 경기 양평군
# 10 양평 대자연 빙어송어축제2017.12.23~2018.02.18
# 11 경기 양평군
# 0 양평빙어축제2017.12.23~2018.02.25
# 1 경기 양평군
# 3 물맑은 양평 산수유마을 빙어축제2017.12.23~2018.02.18
# 4 경기 양평군
# 6 평창송어축제2017.12.22~2018.02.25
# 7 강원 평창군
# 9 인제빙어축제2018.01.27~2018.02.04
# 10 강원 인제군
# 12 강화빙어축제2018.01.01~2018.02.24
# 13 인천 강화군
# 15 청평설빙송어빙어축제2017.12.29~2018.02.25
# 16 경기 가평군
# 0 안성빙어축제2017.12.23~2018.02.18
# 1 경기 안성시
# 3 청평 얼음꽃 송어 축제2017.12.23~2018.02.25
# 4 경기 가평군
# 6 강화도 송어 빙어 축제2017.12.23~2018.03.04
# 7 인천 강화군
# 9 양주송어축제2017.12.22~2018.02.25
# 10 경기 양주시
# 12 강화도 빙어 송어 축제2017.12.15~2018.02.28
# 13 인천 강화군
# 0 대관령 눈꽃축제2018.02.07~2018.02.25
# 1 강원 평창군
# 2 태백산눈축제2018.01.19~2018.02.11
# 3 강원 태백시
# 4 포천 백운계곡 동장군축제2017.12.30~2018.01.28
# 5 경기 포천시
# 6 지리산 남원 바래봉 눈꽃축제2017.12.30~2018.02.11
# 7 전북 남원시
# 8 부곡하와이 얼음조각축제2016.12.24~2017.01.30
# 9 경남 창녕군
# 10 칠갑산얼음분수축제2017.12.23~2018.02.18
# 11 충남 청양군
# 0 얼음나라 화천산천어축제2018.01.06~2018.01.28
# 1 강원 화천군
# 2 가평자라섬씽씽축제2018.01.06~2018.02.18
# 3 경기 가평군
# 4 홍천강 인삼송어 축제2018.01.05~2018.01.21
# 5 강원 홍천군
# 6 파주 송어 축제2017.12.23~2018.02.18
# 7 경기 파주시
# 8 물맑은 양평빙어축제2017.12.23~2018.02.18
# 9 경기 양평군
# 10 양평 대자연 빙어송어축제2017.12.23~2018.02.18
# 11 경기 양평군
# 0 양평빙어축제2017.12.23~2018.02.25
# 1 경기 양평군
# 3 물맑은 양평 산수유마을 빙어축제2017.12.23~2018.02.18
# 4 경기 양평군
# 6 평창송어축제2017.12.22~2018.02.25
# 7 강원 평창군
# 9 인제빙어축제2018.01.27~2018.02.04
# 10 강원 인제군
# 12 강화빙어축제2018.01.01~2018.02.24
# 13 인천 강화군
# 15 청평설빙송어빙어축제2017.12.29~2018.02.25
# 16 경기 가평군
# 0 안성빙어축제2017.12.23~2018.02.18
# 1 경기 안성시
# 3 청평 얼음꽃 송어 축제2017.12.23~2018.02.25
# 4 경기 가평군
# 6 강화도 송어 빙어 축제2017.12.23~2018.03.04
# 7 인천 강화군
# 9 양주송어축제2017.12.22~2018.02.25
# 10 경기 양주시
# 12 강화도 빙어 송어 축제2017.12.15~2018.02.28
# 13 인천 강화군
# 0 얼음나라 화천산천어축제2018.01.06~2018.01.28
# 1 강원 화천군
# 2 가평자라섬씽씽축제2018.01.06~2018.02.18
# 3 경기 가평군
# 4 홍천강 인삼송어 축제2018.01.05~2018.01.21
# 5 강원 홍천군
# 6 파주 송어 축제2017.12.23~2018.02.18
# 7 경기 파주시
# 8 물맑은 양평빙어축제2017.12.23~2018.02.18
# 9 경기 양평군
# 10 양평 대자연 빙어송어축제2017.12.23~2018.02.18
# 11 경기 양평군
# 0 양평빙어축제2017.12.23~2018.02.25
# 1 경기 양평군
# 3 물맑은 양평 산수유마을 빙어축제2017.12.23~2018.02.18
# 4 경기 양평군
# 6 평창송어축제2017.12.22~2018.02.25
# 7 강원 평창군
# 9 인제빙어축제2018.01.27~2018.02.04
# 10 강원 인제군
# 12 강화빙어축제2018.01.01~2018.02.24
# 13 인천 강화군
# 15 청평설빙송어빙어축제2017.12.29~2018.02.25
# 16 경기 가평군
# 0 안성빙어축제2017.12.23~2018.02.18
# 1 경기 안성시
# 3 청평 얼음꽃 송어 축제2017.12.23~2018.02.25
# 4 경기 가평군
# 6 강화도 송어 빙어 축제2017.12.23~2018.03.04
# 7 인천 강화군
# 9 양주송어축제2017.12.22~2018.02.25
# 10 경기 양주시
# 12 강화도 빙어 송어 축제2017.12.15~2018.02.28
# 13 인천 강화군
